# %% [markdown]
# # Anonymisation de données

# %% [markdown]
# ## Imports

# %%
from pprint import pprint
from faker import Faker
from faker.providers import internet

# %% [markdown]
# "Faker is a Python package that generates fake data for you. Whether you need to bootstrap your database, create good-looking XML documents, fill-in your persistence to stress test it, or anonymize data taken from a production service, Faker is for you."
#
# https://faker.readthedocs.io/en/master/

# %% [markdown]
# "Use `faker.Faker()` to create and initialize a faker generator, which can generate data by accessing properties named after the type of data you want."

# %%
fake = Faker()

# %% [markdown]
# ## Créer un faux nom

# %%
print(fake.name())
# Out:
# Anne Collins

# %%
# Il est possible de créer plusieurs faux noms, ici en français, avec une boucle.
fake_fr = Faker('fr_FR')
for _ in range(10):
    print(fake_fr.name())
# Out:
# Noémi François
# Claire Arnaud
# Luc Leconte
# Timothée Jacquot
# Jules du Duval
# Aurore Ledoux Le Olivier
# Olivie Perrier-Jacob
# Geneviève Guillot
# Timothée Perrier
# Adélaïde Durand Le Maillard

# %%
# Même chose en néerlandais.
fake_nl = Faker('nl_NL')
for _ in range(10):
    print(fake_nl.name())
# Out:
# Xavi Melet
# Olivier Verhaar
# Niels van den Hoek
# Joëlle Heijmen
# Roan van Olst
# Jasmijn Simonis
# Yusuf Verbeek
# Lynn Schokman
# Esmee Karels
# Maya van Beeck Beeckmans

# %% [markdown]
# ## Créer une fausse adresse

# %%
# Pour créer une fausse adresse.
print(fake.address())
# Out:
# Unit 6848 Box 6269
# DPO AA 73127

# %% [markdown]
# ## Créer une fausse adresse IP

# %%
fake.add_provider(internet)
print(fake.ipv4_public())
# Out:
# 219.3.128.23

# %% [markdown]
# ## Créer un faux profil complet

# %%
profile = fake_fr.simple_profile()
pprint(profile)
# Out:
# {'address': '3, rue de Lucas\n81201 Pinto-sur-Couturier',
#  'birthdate': datetime.date(2024, 8, 24),
#  'mail': 'charrierlaurence@free.fr',
#  'name': 'Caroline Verdier-Wagner',
#  'sex': 'F',
#  'username': 'bchartier'}
